# %%
from decouple import AutoConfig

# %%
import pytz
from datetime import datetime
from decimal import Decimal

def transform_alphavantage_result(timestamp_str, result):
    # unix_timestamp = result.get('t') / 1000.0
    # utc_timestamp = datetime.fromtimestamp(unix_timestamp, tz = pytz.timezone('UTC'))
    timestamp_format = '%Y-%m-%d %H:%M:%S' # dateutils
    eastern = pytz.timezone('US/Eastern')
    utc = pytz.utc
    utc_timestamp = eastern.localize(datetime.strptime(timestamp_str, timestamp_format)).astimezone(utc)
    return {
        'open_price' : Decimal(result['1. open']),
        'close_price' : Decimal(result['4. close']),
        'high_price' : Decimal(result['2. high']),
        'low_price' : Decimal(result['3. low']),
        'number_of_trades' : None,
        'volume' : int(result['5. volume']),
        'volume_weighted_average' : None,
        'time' : utc_timestamp
    }

# %%
import pytz
from datetime import datetime
from typing import Literal
from dataclasses import dataclass
from urllib.parse import urlencode

ALPHA_VANTAGE_API_KEY = config("ALPHA_VANTAGE_API_KEY", default=None, cast = str)

@dataclass
class AlphaVantageAPIClient:
    ticker : str = "AAPL"
    function : Literal["TIME_SERIES_INTRADAY"] = "TIME_SERIES_INTRADAY"
    interval : Literal["1min", "5min", "15min", "30min", "60min"] = "1min"
    api_key : str = ""
    month : str = "2025-07"

    def get_api_key(self):
        return self.api_key or ALPHA_VANTAGE_API_KEY

        
    def get_params(self):
        return {
            "apikey" : self.get_api_key(),
            "symbol" : self.ticker,
            "interval" : self.interval,
            "function" : self.function,
            "month" : self.month,
        }

    def get_headers(self):
        api_key = self.get_api_key()
        return {}
    
    def generate_url(self, pass_auth= False):
        path = "/query"
        url = f"https://www.alphavantage.co{path}"
        params = self.get_params()
        encoded_params = urlencode(params)
        url = f"{url}?{encoded_params}"
        if pass_auth:
            api_key = self.get_api_key()
            url += f"&apiKey={api_key}"
            
        return url

    def fetch_data(self):
        headers = self.get_headers()
        url = self.generate_url()
        response = requests.get(url, headers=headers)
        response.raise_for_status() # not 200/201
        return response.json()

    def get_stock_data(self):
        data = self.fetch_data()
        dataset_key = [x for x in list(data.keys()) if not x.lower() == "meta data"][0]
        results = data[dataset_key]
        dataset = []
        for timestamp_str in results.keys():
            dataset.append(
                transform_alphavantage_result(timestamp_str, results.get(timestamp_str))
            )
        return dataset

# %%
stock_api_client = AlphaVantageAPIClient()
dataset = stock_client.get_stock_data()

# %%
dataset
# Out:
# [{'open_price': Decimal('208.8000'),
#   'close_price': Decimal('208.7300'),
#   'high_price': Decimal('208.8300'),
#   'low_price': Decimal('208.6573'),
#   'volume': 9694,
#   'time': datetime.datetime(2025, 7, 30, 23, 59, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.8900'),
#   'close_price': Decimal('208.8004'),
#   'high_price': Decimal('208.9000'),
#   'low_price': Decimal('208.8004'),
#   'volume': 7653,
#   'time': datetime.datetime(2025, 7, 30, 23, 58, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.8900'),
#   'close_price': Decimal('208.9000'),
#   'high_price': Decimal('208.9200'),
#   'low_price': Decimal('208.8200'),
#   'volume': 2150,
#   'time': datetime.datetime(2025, 7, 30, 23, 57, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.9054'),
#   'close_price': Decimal('208.9000'),
#   'high_price': Decimal('208.9200'),
#   'low_price': Decimal('208.8200'),
#   'volume': 4675,
#   'time': datetime.datetime(2025, 7, 30, 23, 56, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.9200'),
#   'close_price': Decimal('208.9200'),
#   'high_price': Decimal('208.9200'),
#   'low_price': Decimal('208.8200'),
#   'volume': 4708,
#   'time': datetime.datetime(2025, 7, 30, 23, 55, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.9000'),
#   'close_price': Decimal('208.9187'),
#   'high_price': Decimal('208.9900'),
#   'low_price': Decimal('208.8900'),
#   'volume': 5834,
#   'time': datetime.datetime(2025, 7, 30, 23, 54, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.8800'),
#   'close_price': Decimal('208.8900'),
#   'high_price': Decimal('208.9200'),
#   'low_price': Decimal('208.8000'),
#   'volume': 1643,
#   'time': datetime.datetime(2025, 7, 30, 23, 53, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.9100'),
#   'close_price': Decimal('208.8000'),
#   'high_price': Decimal('208.9100'),
#   'low_price': Decimal('208.7834'),
#   'volume': 1533,
#   'time': datetime.datetime(2025, 7, 30, 23, 52, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.9001'),
#   'close_price': Decimal('208.9022'),
#   'high_price': Decimal('208.9200'),
#   'low_price': Decimal('208.9000'),
#   'volume': 1445,
#   'time': datetime.datetime(2025, 7, 30, 23, 51, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.8401'),
#   'close_price': Decimal('208.9020'),
#   'high_price': Decimal('208.9200'),
#   'low_price': Decimal('208.8401'),
#   'volume': 810,
#   'time': datetime.datetime(2025, 7, 30, 23, 50, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.9900'),
#   'close_price': Decimal('208.9100'),
#   'high_price': Decimal('208.9900'),
#   'low_price': Decimal('208.8800'),
#   'volume': 4497,
#   'time': datetime.datetime(2025, 7, 30, 23, 49, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.9800'),
#   'close_price': Decimal('208.9800'),
#   'high_price': Decimal('208.9800'),
#   'low_price': Decimal('208.9500'),
#   'volume': 5095,
#   'time': datetime.datetime(2025, 7, 30, 23, 48, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.9800'),
#   'close_price': Decimal('208.9710'),
#   'high_price': Decimal('208.9800'),
#   'low_price': Decimal('208.9500'),
#   'volume': 1886,
#   'time': datetime.datetime(2025, 7, 30, 23, 47, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.8500'),
#   'close_price': Decimal('208.9800'),
#   'high_price': Decimal('208.9800'),
#   'low_price': Decimal('208.7932'),
#   'volume': 3607,
#   'time': datetime.datetime(2025, 7, 30, 23, 46, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.7300'),
#   'close_price': Decimal('208.8900'),
#   'high_price': Decimal('208.9200'),
#   'low_price': Decimal('208.7300'),
#   'volume': 4398,
#   'time': datetime.datetime(2025, 7, 30, 23, 45, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.7000'),
#   'close_price': Decimal('208.7400'),
#   'high_price': Decimal('208.7400'),
#   'low_price': Decimal('208.6900'),
#   'volume': 4254,
#   'time': datetime.datetime(2025, 7, 30, 23, 44, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.6496'),
#   'close_price': Decimal('208.7299'),
#   'high_price': Decimal('208.7400'),
#   'low_price': Decimal('208.6496'),
#   'volume': 1055,
#   'time': datetime.datetime(2025, 7, 30, 23, 43, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.6301'),
#   'close_price': Decimal('208.6500'),
#   'high_price': Decimal('208.7372'),
#   'low_price': Decimal('208.6301'),
#   'volume': 3342,
#   'time': datetime.datetime(2025, 7, 30, 23, 42, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.6300'),
#   'close_price': Decimal('208.6500'),
#   'high_price': Decimal('208.6500'),
#   'low_price': Decimal('208.6300'),
#   'volume': 690,
#   'time': datetime.datetime(2025, 7, 30, 23, 41, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.6400'),
#   'close_price': Decimal('208.6499'),
#   'high_price': Decimal('208.6500'),
#   'low_price': Decimal('208.5700'),
#   'volume': 1376,
#   'time': datetime.datetime(2025, 7, 30, 23, 40, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.6900'),
#   'close_price': Decimal('208.6500'),
#   'high_price': Decimal('208.7000'),
#   'low_price': Decimal('208.5700'),
#   'volume': 771,
#   'time': datetime.datetime(2025, 7, 30, 23, 39, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.6500'),
#   'close_price': Decimal('208.6900'),
#   'high_price': Decimal('208.7000'),
#   'low_price': Decimal('208.5700'),
#   'volume': 2029,
#   'time': datetime.datetime(2025, 7, 30, 23, 38, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.7000'),
#   'close_price': Decimal('208.6500'),
#   'high_price': Decimal('208.7000'),
#   'low_price': Decimal('208.6500'),
#   'volume': 719,
#   'time': datetime.datetime(2025, 7, 30, 23, 37, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.6000'),
#   'close_price': Decimal('208.6000'),
#   'high_price': Decimal('208.7000'),
#   'low_price': Decimal('208.5600'),
#   'volume': 1364,
#   'time': datetime.datetime(2025, 7, 30, 23, 36, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.5500'),
#   'close_price': Decimal('208.5700'),
#   'high_price': Decimal('208.6000'),
#   'low_price': Decimal('208.5500'),
#   'volume': 549,
#   'time': datetime.datetime(2025, 7, 30, 23, 35, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.5700'),
#   'close_price': Decimal('208.6000'),
#   'high_price': Decimal('208.6000'),
#   'low_price': Decimal('208.5100'),
#   'volume': 1299,
#   'time': datetime.datetime(2025, 7, 30, 23, 34, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.6888'),
#   'close_price': Decimal('208.5975'),
#   'high_price': Decimal('208.7000'),
#   'low_price': Decimal('208.4139'),
#   'volume': 2450,
#   'time': datetime.datetime(2025, 7, 30, 23, 33, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.7100'),
#   'close_price': Decimal('208.6900'),
#   'high_price': Decimal('208.7200'),
#   'low_price': Decimal('208.6200'),
#   'volume': 1794,
#   'time': datetime.datetime(2025, 7, 30, 23, 32, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.7300'),
#   'close_price': Decimal('208.7199'),
#   'high_price': Decimal('208.7400'),
#   'low_price': Decimal('208.6000'),
#   'volume': 2841,
#   'time': datetime.datetime(2025, 7, 30, 23, 31, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.7300'),
#   'close_price': Decimal('208.7400'),
#   'high_price': Decimal('208.7400'),
#   'low_price': Decimal('208.7000'),
#   'volume': 1998,
#   'time': datetime.datetime(2025, 7, 30, 23, 30, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.7400'),
#   'close_price': Decimal('208.7300'),
#   'high_price': Decimal('208.7400'),
#   'low_price': Decimal('208.6900'),
#   'volume': 4791,
#   'time': datetime.datetime(2025, 7, 30, 23, 29, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.7300'),
#   'close_price': Decimal('208.7399'),
#   'high_price': Decimal('208.7400'),
#   'low_price': Decimal('208.7000'),
#   'volume': 657,
#   'time': datetime.datetime(2025, 7, 30, 23, 28, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.7000'),
#   'close_price': Decimal('208.7400'),
#   'high_price': Decimal('208.7500'),
#   'low_price': Decimal('208.7000'),
#   'volume': 6403,
#   'time': datetime.datetime(2025, 7, 30, 23, 27, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.7300'),
#   'close_price': Decimal('208.7000'),
#   'high_price': Decimal('208.7400'),
#   'low_price': Decimal('208.7000'),
#   'volume': 5568,
#   'time': datetime.datetime(2025, 7, 30, 23, 26, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.7400'),
#   'close_price': Decimal('208.7400'),
#   'high_price': Decimal('208.7600'),
#   'low_price': Decimal('208.7000'),
#   'volume': 2407,
#   'time': datetime.datetime(2025, 7, 30, 23, 25, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.7400'),
#   'close_price': Decimal('208.7397'),
#   'high_price': Decimal('208.7900'),
#   'low_price': Decimal('208.7300'),
#   'volume': 3893,
#   'time': datetime.datetime(2025, 7, 30, 23, 24, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.7300'),
#   'close_price': Decimal('208.7300'),
#   'high_price': Decimal('208.7800'),
#   'low_price': Decimal('208.7201'),
#   'volume': 1971,
#   'time': datetime.datetime(2025, 7, 30, 23, 23, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.7400'),
#   'close_price': Decimal('208.7300'),
#   'high_price': Decimal('208.7400'),
#   'low_price': Decimal('208.6900'),
#   'volume': 1456,
#   'time': datetime.datetime(2025, 7, 30, 23, 22, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.6300'),
#   'close_price': Decimal('208.7400'),
#   'high_price': Decimal('208.7400'),
#   'low_price': Decimal('208.6000'),
#   'volume': 1810,
#   'time': datetime.datetime(2025, 7, 30, 23, 21, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.7300'),
#   'close_price': Decimal('208.7400'),
#   'high_price': Decimal('208.7400'),
#   'low_price': Decimal('208.6010'),
#   'volume': 2240,
#   'time': datetime.datetime(2025, 7, 30, 23, 20, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.7400'),
#   'close_price': Decimal('208.7360'),
#   'high_price': Decimal('208.7400'),
#   'low_price': Decimal('208.5000'),
#   'volume': 3088,
#   'time': datetime.datetime(2025, 7, 30, 23, 19, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.6000'),
#   'close_price': Decimal('208.6900'),
#   'high_price': Decimal('208.7500'),
#   'low_price': Decimal('208.6000'),
#   'volume': 1106,
#   'time': datetime.datetime(2025, 7, 30, 23, 18, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.6001'),
#   'close_price': Decimal('208.6100'),
#   'high_price': Decimal('208.7500'),
#   'low_price': Decimal('208.6000'),
#   'volume': 2634,
#   'time': datetime.datetime(2025, 7, 30, 23, 17, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.5800'),
#   'close_price': Decimal('208.6500'),
#   'high_price': Decimal('208.6700'),
#   'low_price': Decimal('208.5000'),
#   'volume': 1431,
#   'time': datetime.datetime(2025, 7, 30, 23, 16, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.6000'),
#   'close_price': Decimal('208.5000'),
#   'high_price': Decimal('208.6700'),
#   'low_price': Decimal('208.5000'),
#   'volume': 2776,
#   'time': datetime.datetime(2025, 7, 30, 23, 15, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.5400'),
#   'close_price': Decimal('208.6000'),
#   'high_price': Decimal('208.6700'),
#   'low_price': Decimal('208.5000'),
#   'volume': 1787,
#   'time': datetime.datetime(2025, 7, 30, 23, 14, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.4800'),
#   'close_price': Decimal('208.6548'),
#   'high_price': Decimal('208.6548'),
#   'low_price': Decimal('208.4500'),
#   'volume': 4863,
#   'time': datetime.datetime(2025, 7, 30, 23, 13, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.5000'),
#   'close_price': Decimal('208.4800'),
#   'high_price': Decimal('208.5000'),
#   'low_price': Decimal('208.4000'),
#   'volume': 470,
#   'time': datetime.datetime(2025, 7, 30, 23, 12, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.4000'),
#   'close_price': Decimal('208.4600'),
#   'high_price': Decimal('208.4600'),
#   'low_price': Decimal('208.4000'),
#   'volume': 281,
#   'time': datetime.datetime(2025, 7, 30, 23, 11, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.3700'),
#   'close_price': Decimal('208.4600'),
#   'high_price': Decimal('208.4600'),
#   'low_price': Decimal('208.3600'),
#   'volume': 945,
#   'time': datetime.datetime(2025, 7, 30, 23, 10, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.3700'),
#   'close_price': Decimal('208.3700'),
#   'high_price': Decimal('208.3700'),
#   'low_price': Decimal('208.3600'),
#   'volume': 594,
#   'time': datetime.datetime(2025, 7, 30, 23, 9, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.3500'),
#   'close_price': Decimal('208.3700'),
#   'high_price': Decimal('208.3700'),
#   'low_price': Decimal('208.3000'),
#   'volume': 1340,
#   'time': datetime.datetime(2025, 7, 30, 23, 8, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.3000'),
#   'close_price': Decimal('208.3000'),
#   'high_price': Decimal('208.3700'),
#   'low_price': Decimal('208.3000'),
#   'volume': 3488,
#   'time': datetime.datetime(2025, 7, 30, 23, 7, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.3699'),
#   'close_price': Decimal('208.3700'),
#   'high_price': Decimal('208.3700'),
#   'low_price': Decimal('208.3487'),
#   'volume': 2241,
#   'time': datetime.datetime(2025, 7, 30, 23, 6, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.3693'),
#   'close_price': Decimal('208.3700'),
#   'high_price': Decimal('208.3700'),
#   'low_price': Decimal('208.3500'),
#   'volume': 1918,
#   'time': datetime.datetime(2025, 7, 30, 23, 5, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.3600'),
#   'close_price': Decimal('208.3700'),
#   'high_price': Decimal('208.3700'),
#   'low_price': Decimal('208.3500'),
#   'volume': 1582,
#   'time': datetime.datetime(2025, 7, 30, 23, 4, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.4400'),
#   'close_price': Decimal('208.3700'),
#   'high_price': Decimal('208.4500'),
#   'low_price': Decimal('208.3500'),
#   'volume': 5327,
#   'time': datetime.datetime(2025, 7, 30, 23, 3, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.4500'),
#   'close_price': Decimal('208.4300'),
#   'high_price': Decimal('208.4500'),
#   'low_price': Decimal('208.4012'),
#   'volume': 2107,
#   'time': datetime.datetime(2025, 7, 30, 23, 2, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.4600'),
#   'close_price': Decimal('208.4500'),
#   'high_price': Decimal('208.4600'),
#   'low_price': Decimal('208.3000'),
#   'volume': 774,
#   'time': datetime.datetime(2025, 7, 30, 23, 1, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.4000'),
#   'close_price': Decimal('208.4200'),
#   'high_price': Decimal('208.4600'),
#   'low_price': Decimal('208.3400'),
#   'volume': 1904,
#   'time': datetime.datetime(2025, 7, 30, 23, 0, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.4600'),
#   'close_price': Decimal('208.4000'),
#   'high_price': Decimal('208.4600'),
#   'low_price': Decimal('208.4000'),
#   'volume': 1768,
#   'time': datetime.datetime(2025, 7, 30, 22, 59, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.4000'),
#   'close_price': Decimal('208.4600'),
#   'high_price': Decimal('208.4600'),
#   'low_price': Decimal('208.3880'),
#   'volume': 519,
#   'time': datetime.datetime(2025, 7, 30, 22, 58, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.4900'),
#   'close_price': Decimal('208.4600'),
#   'high_price': Decimal('208.5000'),
#   'low_price': Decimal('208.3000'),
#   'volume': 1638,
#   'time': datetime.datetime(2025, 7, 30, 22, 57, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.4000'),
#   'close_price': Decimal('208.5000'),
#   'high_price': Decimal('208.5000'),
#   'low_price': Decimal('208.4000'),
#   'volume': 4666,
#   'time': datetime.datetime(2025, 7, 30, 22, 56, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.4500'),
#   'close_price': Decimal('208.4700'),
#   'high_price': Decimal('208.4700'),
#   'low_price': Decimal('208.3000'),
#   'volume': 9901,
#   'time': datetime.datetime(2025, 7, 30, 22, 55, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.4300'),
#   'close_price': Decimal('208.4600'),
#   'high_price': Decimal('208.4900'),
#   'low_price': Decimal('208.4000'),
#   'volume': 1151,
#   'time': datetime.datetime(2025, 7, 30, 22, 54, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.4000'),
#   'close_price': Decimal('208.4000'),
#   'high_price': Decimal('208.4300'),
#   'low_price': Decimal('208.3900'),
#   'volume': 4660,
#   'time': datetime.datetime(2025, 7, 30, 22, 53, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.4700'),
#   'close_price': Decimal('208.4200'),
#   'high_price': Decimal('208.4700'),
#   'low_price': Decimal('208.3900'),
#   'volume': 1224,
#   'time': datetime.datetime(2025, 7, 30, 22, 52, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.4700'),
#   'close_price': Decimal('208.4200'),
#   'high_price': Decimal('208.4700'),
#   'low_price': Decimal('208.3900'),
#   'volume': 2391,
#   'time': datetime.datetime(2025, 7, 30, 22, 51, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.3900'),
#   'close_price': Decimal('208.4300'),
#   'high_price': Decimal('208.4300'),
#   'low_price': Decimal('208.3900'),
#   'volume': 3508,
#   'time': datetime.datetime(2025, 7, 30, 22, 50, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.3200'),
#   'close_price': Decimal('208.3800'),
#   'high_price': Decimal('208.3800'),
#   'low_price': Decimal('208.3000'),
#   'volume': 1600,
#   'time': datetime.datetime(2025, 7, 30, 22, 49, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.3200'),
#   'close_price': Decimal('208.3500'),
#   'high_price': Decimal('208.3900'),
#   'low_price': Decimal('208.2900'),
#   'volume': 1076,
#   'time': datetime.datetime(2025, 7, 30, 22, 48, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.2900'),
#   'close_price': Decimal('208.3200'),
#   'high_price': Decimal('208.3900'),
#   'low_price': Decimal('208.2800'),
#   'volume': 5547,
#   'time': datetime.datetime(2025, 7, 30, 22, 47, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.2800'),
#   'close_price': Decimal('208.2800'),
#   'high_price': Decimal('208.2900'),
#   'low_price': Decimal('208.2800'),
#   'volume': 2632,
#   'time': datetime.datetime(2025, 7, 30, 22, 46, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.2803'),
#   'close_price': Decimal('208.2900'),
#   'high_price': Decimal('208.2900'),
#   'low_price': Decimal('208.2800'),
#   'volume': 912,
#   'time': datetime.datetime(2025, 7, 30, 22, 45, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.2800'),
#   'close_price': Decimal('208.2800'),
#   'high_price': Decimal('208.2900'),
#   'low_price': Decimal('208.2600'),
#   'volume': 798,
#   'time': datetime.datetime(2025, 7, 30, 22, 44, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.2800'),
#   'close_price': Decimal('208.2800'),
#   'high_price': Decimal('208.2900'),
#   'low_price': Decimal('208.2200'),
#   'volume': 1532,
#   'time': datetime.datetime(2025, 7, 30, 22, 43, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.2700'),
#   'close_price': Decimal('208.2900'),
#   'high_price': Decimal('208.2900'),
#   'low_price': Decimal('208.1800'),
#   'volume': 1280,
#   'time': datetime.datetime(2025, 7, 30, 22, 42, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.2600'),
#   'close_price': Decimal('208.2900'),
#   'high_price': Decimal('208.3800'),
#   'low_price': Decimal('208.0500'),
#   'volume': 6395,
#   'time': datetime.datetime(2025, 7, 30, 22, 41, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.2400'),
#   'close_price': Decimal('208.2600'),
#   'high_price': Decimal('208.2800'),
#   'low_price': Decimal('208.2100'),
#   'volume': 1459,
#   'time': datetime.datetime(2025, 7, 30, 22, 40, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.1800'),
#   'close_price': Decimal('208.2400'),
#   'high_price': Decimal('208.2500'),
#   'low_price': Decimal('208.1800'),
#   'volume': 3304,
#   'time': datetime.datetime(2025, 7, 30, 22, 39, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.1550'),
#   'close_price': Decimal('208.2000'),
#   'high_price': Decimal('208.2000'),
#   'low_price': Decimal('208.1500'),
#   'volume': 6060,
#   'time': datetime.datetime(2025, 7, 30, 22, 38, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.1500'),
#   'close_price': Decimal('208.1999'),
#   'high_price': Decimal('208.2500'),
#   'low_price': Decimal('208.1500'),
#   'volume': 3322,
#   'time': datetime.datetime(2025, 7, 30, 22, 37, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.2000'),
#   'close_price': Decimal('208.1950'),
#   'high_price': Decimal('208.2000'),
#   'low_price': Decimal('208.1200'),
#   'volume': 1531,
#   'time': datetime.datetime(2025, 7, 30, 22, 36, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.1100'),
#   'close_price': Decimal('208.1300'),
#   'high_price': Decimal('208.2000'),
#   'low_price': Decimal('208.0800'),
#   'volume': 1588,
#   'time': datetime.datetime(2025, 7, 30, 22, 35, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.0498'),
#   'close_price': Decimal('208.1500'),
#   'high_price': Decimal('208.1500'),
#   'low_price': Decimal('207.8100'),
#   'volume': 1374,
#   'time': datetime.datetime(2025, 7, 30, 22, 34, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.1100'),
#   'close_price': Decimal('208.0500'),
#   'high_price': Decimal('208.1100'),
#   'low_price': Decimal('208.0400'),
#   'volume': 6219,
#   'time': datetime.datetime(2025, 7, 30, 22, 33, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.1000'),
#   'close_price': Decimal('208.1086'),
#   'high_price': Decimal('208.1100'),
#   'low_price': Decimal('208.0600'),
#   'volume': 1982,
#   'time': datetime.datetime(2025, 7, 30, 22, 32, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.0900'),
#   'close_price': Decimal('208.0900'),
#   'high_price': Decimal('208.0900'),
#   'low_price': Decimal('208.0800'),
#   'volume': 2904,
#   'time': datetime.datetime(2025, 7, 30, 22, 31, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.0800'),
#   'close_price': Decimal('208.0800'),
#   'high_price': Decimal('208.0900'),
#   'low_price': Decimal('208.0800'),
#   'volume': 1539,
#   'time': datetime.datetime(2025, 7, 30, 22, 30, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.1000'),
#   'close_price': Decimal('208.0800'),
#   'high_price': Decimal('208.1100'),
#   'low_price': Decimal('208.0627'),
#   'volume': 2684,
#   'time': datetime.datetime(2025, 7, 30, 22, 29, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.1000'),
#   'close_price': Decimal('208.1094'),
#   'high_price': Decimal('208.1100'),
#   'low_price': Decimal('208.0500'),
#   'volume': 862,
#   'time': datetime.datetime(2025, 7, 30, 22, 28, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.1091'),
#   'close_price': Decimal('208.1096'),
#   'high_price': Decimal('208.1100'),
#   'low_price': Decimal('208.0000'),
#   'volume': 637,
#   'time': datetime.datetime(2025, 7, 30, 22, 27, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.1100'),
#   'close_price': Decimal('208.0000'),
#   'high_price': Decimal('208.1100'),
#   'low_price': Decimal('208.0000'),
#   'volume': 1300,
#   'time': datetime.datetime(2025, 7, 30, 22, 26, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.2000'),
#   'close_price': Decimal('208.1100'),
#   'high_price': Decimal('208.2500'),
#   'low_price': Decimal('208.1000'),
#   'volume': 1630,
#   'time': datetime.datetime(2025, 7, 30, 22, 25, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.1800'),
#   'close_price': Decimal('208.2300'),
#   'high_price': Decimal('208.2500'),
#   'low_price': Decimal('208.0900'),
#   'volume': 1942,
#   'time': datetime.datetime(2025, 7, 30, 22, 24, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.0000'),
#   'close_price': Decimal('208.0600'),
#   'high_price': Decimal('208.2500'),
#   'low_price': Decimal('207.9800'),
#   'volume': 4047,
#   'time': datetime.datetime(2025, 7, 30, 22, 23, tzinfo=<UTC>)},
#  {'open_price': Decimal('207.9900'),
#   'close_price': Decimal('207.9800'),
#   'high_price': Decimal('209.0500'),
#   'low_price': Decimal('207.7200'),
#   'volume': 1437239,
#   'time': datetime.datetime(2025, 7, 30, 22, 22, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.0000'),
#   'close_price': Decimal('207.9900'),
#   'high_price': Decimal('208.0000'),
#   'low_price': Decimal('207.9000'),
#   'volume': 4204,
#   'time': datetime.datetime(2025, 7, 30, 22, 21, tzinfo=<UTC>)},
#  {'open_price': Decimal('208.0000'),
#   'close_price': Decimal('207.9999'),
#   'high_price': Decimal('208.0000'),
#   'low_price': Decimal('207.9500'),
#   'volume': 4305,
#   'time': datetime.datetime(2025, 7, 30, 22, 20, tzinfo=<UTC>)}]
