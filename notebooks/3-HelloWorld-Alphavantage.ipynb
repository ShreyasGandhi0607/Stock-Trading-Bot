# %%
from decouple import AutoConfig

# %%
config = AutoConfig(search_path="..")

# %%
assert config("ALPHA_VANTAGE_API_KEY", default=None, cast = str) is not None

# %%
ALPHA_VANTAGE_API_KEY = config("ALPHA_VANTAGE_API_KEY", default=None, cast = str)

# %%
# ALPHA_VANTAGE_API_KEY

# %%
import requests

api_key = ALPHA_VANTAGE_API_KEY

params = {
    "api_key" : ALPHA_VANTAGE_API_KEY,
    "ticker" : "AAPL",
    "function" : "TIME_SERIES_DAILY"
}

url = 'https://www.alphavantage.co/query?function={function}&symbol={ticker}&apikey={api_key}'.format(
    **params
)
r = requests.get(url)
data = r.json()

# %%
data
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'AAPL',
#   '3. Last Refreshed': '2025-07-30',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2025-07-30': {'1. open': '211.8950',
#    '2. high': '212.3900',
#    '3. low': '207.7200',
#    '4. close': '209.0500',
#    '5. volume': '45512514'},
#   '2025-07-29': {'1. open': '214.1750',
#    '2. high': '214.8100',
#    '3. low': '210.8200',
#    '4. close': '211.2700',
#    '5. volume': '51411723'},
#   '2025-07-28': {'1. open': '214.0300',
#    '2. high': '214.8450',
#    '3. low': '213.0600',
#    '4. close': '214.0500',
#    '5. volume': '37858017'},
#   '2025-07-25': {'1. open': '214.7000',
#    '2. high': '215.2400',
#    '3. low': '213.4000',
#    '4. close': '213.8800',
#    '5. volume': '40268781'},
#   '2025-07-24': {'1. open': '213.9000',
#    '2. high': '215.6900',
#    '3. low': '213.5300',
#    '4. close': '213.7600',
#    '5. volume': '46022620'},
#   '2025-07-23': {'1. open': '215.0000',
#    '2. high': '215.1500',
#    '3. low': '212.4100',
#    '4. close': '214.1500',
#    '5. volume': '46989301'},
#   '2025-07-22': {'1. open': '213.1400',
#    '2. high': '214.9500',
#    '3. low': '212.2301',
#    '4. close': '214.4000',
#    '5. volume': '46404072'},
#   '2025-07-21': {'1. open': '212.1000',
#    '2. high': '215.7800',
#    '3. low': '211.6300',
#    '4. close': '212.4800',
#    '5. volume': '51377434'},
#   '2025-07-18': {'1. open': '210.8700',
#    '2. high': '211.7900',
#    '3. low': '209.7045',
#    '4. close': '211.1800',
#    '5. volume': '48974591'},
#   '2025-07-17': {'1. open': '210.5700',
#    '2. high': '211.8000',
#    '3. low': '209.5900',
#    '4. close': '210.0200',
#    '5. volume': '48068141'},
#   '2025-07-16': {'1. open': '210.2950',
#    '2. high': '212.4000',
#    '3. low': '208.6400',
#    '4. close': '210.1600',
#    '5. volume': '47490532'},
#   '2025-07-15': {'1. open': '209.2200',
#    '2. high': '211.8900',
#    '3. low': '208.9200',
#    '4. close': '209.1100',
#    '5. volume': '42296339'},
#   '2025-07-14': {'1. open': '209.9250',
#    '2. high': '210.9100',
#    '3. low': '207.5400',
#    '4. close': '208.6200',
#    '5. volume': '38840111'},
#   '2025-07-11': {'1. open': '210.5650',
#    '2. high': '212.1300',
#    '3. low': '209.8600',
#    '4. close': '211.1600',
#    '5. volume': '39765812'},
#   '2025-07-10': {'1. open': '210.5050',
#    '2. high': '213.4800',
#    '3. low': '210.0300',
#    '4. close': '212.4100',
#    '5. volume': '44443635'},
#   '2025-07-09': {'1. open': '209.5300',
#    '2. high': '211.3300',
#    '3. low': '207.2200',
#    '4. close': '211.1400',
#    '5. volume': '48749367'},
#   '2025-07-08': {'1. open': '210.1000',
#    '2. high': '211.4300',
#    '3. low': '208.4500',
#    '4. close': '210.0100',
#    '5. volume': '42848928'},
#   '2025-07-07': {'1. open': '212.6800',
#    '2. high': '216.2300',
#    '3. low': '208.8000',
#    '4. close': '209.9500',
#    '5. volume': '50228984'},
#   '2025-07-03': {'1. open': '212.1450',
#    '2. high': '214.6500',
#    '3. low': '211.8101',
#    '4. close': '213.5500',
#    '5. volume': '34955836'},
#   '2025-07-02': {'1. open': '208.9100',
#    '2. high': '213.3400',
#    '3. low': '208.1400',
#    '4. close': '212.4400',
#    '5. volume': '67941811'},
#   '2025-07-01': {'1. open': '206.6650',
#    '2. high': '210.1865',
#    '3. low': '206.1401',
#    '4. close': '207.8200',
#    '5. volume': '78788867'},
#   '2025-06-30': {'1. open': '202.0100',
#    '2. high': '207.3900',
#    '3. low': '199.2607',
#    '4. close': '205.1700',
#    '5. volume': '91912816'},
#   '2025-06-27': {'1. open': '201.8900',
#    '2. high': '203.2200',
#    '3. low': '200.0000',
#    '4. close': '201.0800',
#    '5. volume': '73188571'},
#   '2025-06-26': {'1. open': '201.4300',
#    '2. high': '202.6400',
#    '3. low': '199.4600',
#    '4. close': '201.0000',
#    '5. volume': '50799121'},
#   '2025-06-25': {'1. open': '201.4500',
#    '2. high': '203.6700',
#    '3. low': '200.6201',
#    '4. close': '201.5600',
#    '5. volume': '39525730'},
#   '2025-06-24': {'1. open': '202.5900',
#    '2. high': '203.4400',
#    '3. low': '200.2000',
#    '4. close': '200.3000',
#    '5. volume': '54064033'},
#   '2025-06-23': {'1. open': '201.6250',
#    '2. high': '202.3000',
#    '3. low': '198.9600',
#    '4. close': '201.5000',
#    '5. volume': '55814272'},
#   '2025-06-20': {'1. open': '198.2350',
#    '2. high': '201.7000',
#    '3. low': '196.8550',
#    '4. close': '201.0000',
#    '5. volume': '96813542'},
#   '2025-06-18': {'1. open': '195.9400',
#    '2. high': '197.5700',
#    '3. low': '195.0700',
#    '4. close': '196.5800',
#    '5. volume': '45394689'},
#   '2025-06-17': {'1. open': '197.2000',
#    '2. high': '198.3900',
#    '3. low': '195.2100',
#    '4. close': '195.6400',
#    '5. volume': '38856152'},
#   '2025-06-16': {'1. open': '197.3000',
#    '2. high': '198.6850',
#    '3. low': '196.5636',
#    '4. close': '198.4200',
#    '5. volume': '43020691'},
#   '2025-06-13': {'1. open': '199.7300',
#    '2. high': '200.3700',
#    '3. low': '195.7000',
#    '4. close': '196.4500',
#    '5. volume': '51447349'},
#   '2025-06-12': {'1. open': '199.0800',
#    '2. high': '199.6800',
#    '3. low': '197.3601',
#    '4. close': '199.2000',
#    '5. volume': '43904635'},
#   '2025-06-11': {'1. open': '203.5000',
#    '2. high': '204.5000',
#    '3. low': '198.4100',
#    '4. close': '198.7800',
#    '5. volume': '60989857'},
#   '2025-06-10': {'1. open': '200.6000',
#    '2. high': '204.3500',
#    '3. low': '200.5700',
#    '4. close': '202.6700',
#    '5. volume': '54672608'},
#   '2025-06-09': {'1. open': '204.3900',
#    '2. high': '206.0000',
#    '3. low': '200.0200',
#    '4. close': '201.4500',
#    '5. volume': '72862557'},
#   '2025-06-06': {'1. open': '203.0000',
#    '2. high': '205.7000',
#    '3. low': '202.0500',
#    '4. close': '203.9200',
#    '5. volume': '46607693'},
#   '2025-06-05': {'1. open': '203.5000',
#    '2. high': '204.7500',
#    '3. low': '200.1500',
#    '4. close': '200.6300',
#    '5. volume': '55221235'},
#   '2025-06-04': {'1. open': '202.9100',
#    '2. high': '206.2400',
#    '3. low': '202.1000',
#    '4. close': '202.8200',
#    '5. volume': '43603985'},
#   '2025-06-03': {'1. open': '201.3500',
#    '2. high': '203.7700',
#    '3. low': '200.9550',
#    '4. close': '203.2700',
#    '5. volume': '46381567'},
#   '2025-06-02': {'1. open': '200.2800',
#    '2. high': '202.1300',
#    '3. low': '200.1200',
#    '4. close': '201.7000',
#    '5. volume': '35423294'},
#   '2025-05-30': {'1. open': '199.3700',
#    '2. high': '201.9600',
#    '3. low': '196.7800',
#    '4. close': '200.8500',
#    '5. volume': '70819942'},
#   '2025-05-29': {'1. open': '203.5750',
#    '2. high': '203.8100',
#    '3. low': '198.5100',
#    '4. close': '199.9500',
#    '5. volume': '51477938'},
#   '2025-05-28': {'1. open': '200.5900',
#    '2. high': '202.7300',
#    '3. low': '199.9000',
#    '4. close': '200.4200',
#    '5. volume': '45339678'},
#   '2025-05-27': {'1. open': '198.3000',
#    '2. high': '200.7400',
#    '3. low': '197.4300',
#    '4. close': '200.2100',
#    '5. volume': '56288475'},
#   '2025-05-23': {'1. open': '193.6650',
#    '2. high': '197.7000',
#    '3. low': '193.4600',
#    '4. close': '195.2700',
#    '5. volume': '78432918'},
#   '2025-05-22': {'1. open': '200.7100',
#    '2. high': '202.7500',
#    '3. low': '199.7000',
#    '4. close': '201.3600',
#    '5. volume': '46742407'},
#   '2025-05-21': {'1. open': '205.1700',
#    '2. high': '207.0400',
#    '3. low': '200.7100',
#    '4. close': '202.0900',
#    '5. volume': '59211774'},
#   '2025-05-20': {'1. open': '207.6700',
#    '2. high': '208.4700',
#    '3. low': '205.0300',
#    '4. close': '206.8600',
#    '5. volume': '42496635'},
#   '2025-05-19': {'1. open': '207.9100',
#    '2. high': '209.4800',
#    '3. low': '204.2600',
#    '4. close': '208.7800',
#    '5. volume': '46140527'},
#   '2025-05-16': {'1. open': '212.3600',
#    '2. high': '212.5700',
#    '3. low': '209.7700',
#    '4. close': '211.2600',
#    '5. volume': '54737850'},
#   '2025-05-15': {'1. open': '210.9500',
#    '2. high': '212.9600',
#    '3. low': '209.5400',
#    '4. close': '211.4500',
#    '5. volume': '45029473'},
#   '2025-05-14': {'1. open': '212.4300',
#    '2. high': '213.9400',
#    '3. low': '210.5801',
#    '4. close': '212.3300',
#    '5. volume': '49325825'},
#   '2025-05-13': {'1. open': '210.4300',
#    '2. high': '213.4000',
#    '3. low': '209.0000',
#    '4. close': '212.9300',
#    '5. volume': '51909332'},
#   '2025-05-12': {'1. open': '210.9700',
#    '2. high': '211.2679',
#    '3. low': '206.7500',
#    '4. close': '210.7900',
#    '5. volume': '63775814'},
#   '2025-05-09': {'1. open': '199.0000',
#    '2. high': '200.5399',
#    '3. low': '197.5350',
#    '4. close': '198.5300',
#    '5. volume': '36453923'},
#   '2025-05-08': {'1. open': '197.7200',
#    '2. high': '200.0500',
#    '3. low': '194.6796',
#    '4. close': '197.4900',
#    '5. volume': '50478872'},
#   '2025-05-07': {'1. open': '199.1700',
#    '2. high': '199.4400',
#    '3. low': '193.2500',
#    '4. close': '196.2500',
#    '5. volume': '68616943'},
#   '2025-05-06': {'1. open': '198.2100',
#    '2. high': '200.6500',
#    '3. low': '197.0200',
#    '4. close': '198.5100',
#    '5. volume': '51216482'},
#   '2025-05-05': {'1. open': '203.1000',
#    '2. high': '204.1000',
#    '3. low': '198.2100',
#    '4. close': '198.8900',
#    '5. volume': '69018452'},
#   '2025-05-02': {'1. open': '206.0900',
#    '2. high': '206.9900',
#    '3. low': '202.1600',
#    '4. close': '205.3500',
#    '5. volume': '101010621'},
#   '2025-05-01': {'1. open': '209.0800',
#    '2. high': '214.5600',
#    '3. low': '208.9000',
#    '4. close': '213.3200',
#    '5. volume': '57365675'},
#   '2025-04-30': {'1. open': '209.3000',
#    '2. high': '213.5800',
#    '3. low': '206.6705',
#    '4. close': '212.5000',
#    '5. volume': '52286454'},
#   '2025-04-29': {'1. open': '208.6930',
#    '2. high': '212.2400',
#    '3. low': '208.3700',
#    '4. close': '211.2100',
#    '5. volume': '36827633'},
#   '2025-04-28': {'1. open': '210.0000',
#    '2. high': '211.5000',
#    '3. low': '207.4600',
#    '4. close': '210.1400',
#    '5. volume': '38743074'},
#   '2025-04-25': {'1. open': '206.3650',
#    '2. high': '209.7500',
#    '3. low': '206.2000',
#    '4. close': '209.2800',
#    '5. volume': '38222258'},
#   '2025-04-24': {'1. open': '204.8900',
#    '2. high': '208.8299',
#    '3. low': '202.9400',
#    '4. close': '208.3700',
#    '5. volume': '47310989'},
#   '2025-04-23': {'1. open': '206.0000',
#    '2. high': '208.0000',
#    '3. low': '202.7990',
#    '4. close': '204.6000',
#    '5. volume': '52929165'},
#   '2025-04-22': {'1. open': '196.1200',
#    '2. high': '201.5900',
#    '3. low': '195.9700',
#    '4. close': '199.7400',
#    '5. volume': '52976371'},
#   '2025-04-21': {'1. open': '193.2650',
#    '2. high': '193.8000',
#    '3. low': '189.8112',
#    '4. close': '193.1600',
#    '5. volume': '46742537'},
#   '2025-04-17': {'1. open': '197.2000',
#    '2. high': '198.8335',
#    '3. low': '194.4200',
#    '4. close': '196.9800',
#    '5. volume': '52164675'},
#   '2025-04-16': {'1. open': '198.3600',
#    '2. high': '200.7000',
#    '3. low': '192.3700',
#    '4. close': '194.2700',
#    '5. volume': '59732423'},
#   '2025-04-15': {'1. open': '201.8550',
#    '2. high': '203.5100',
#    '3. low': '199.8000',
#    '4. close': '202.1400',
#    '5. volume': '51343872'},
#   '2025-04-14': {'1. open': '211.4400',
#    '2. high': '212.9400',
#    '3. low': '201.1621',
#    '4. close': '202.5200',
#    '5. volume': '101352911'},
#   '2025-04-11': {'1. open': '186.1000',
#    '2. high': '199.5400',
#    '3. low': '186.0600',
#    '4. close': '198.1500',
#    '5. volume': '87435915'},
#   '2025-04-10': {'1. open': '189.0650',
#    '2. high': '194.7799',
#    '3. low': '183.0000',
#    '4. close': '190.4200',
#    '5. volume': '121879981'},
#   '2025-04-09': {'1. open': '171.9500',
#    '2. high': '200.6100',
#    '3. low': '171.8900',
#    '4. close': '198.8500',
#    '5. volume': '184395885'},
#   '2025-04-08': {'1. open': '186.7000',
#    '2. high': '190.3350',
#    '3. low': '169.2101',
#    '4. close': '172.4200',
#    '5. volume': '120859491'},
#   '2025-04-07': {'1. open': '177.2000',
#    '2. high': '194.1500',
#    '3. low': '174.6200',
#    '4. close': '181.4600',
#    '5. volume': '160466286'},
#   '2025-04-04': {'1. open': '193.8900',
#    '2. high': '199.8800',
#    '3. low': '187.3400',
#    '4. close': '188.3800',
#    '5. volume': '125910913'},
#   '2025-04-03': {'1. open': '205.5400',
#    '2. high': '207.4900',
#    '3. low': '201.2500',
#    '4. close': '203.1900',
#    '5. volume': '103419006'},
#   '2025-04-02': {'1. open': '221.3150',
#    '2. high': '225.1900',
#    '3. low': '221.0200',
#    '4. close': '223.8900',
#    '5. volume': '35905904'},
#   '2025-04-01': {'1. open': '219.8050',
#    '2. high': '223.6800',
#    '3. low': '218.9000',
#    '4. close': '223.1900',
#    '5. volume': '36412740'},
#   '2025-03-31': {'1. open': '217.0050',
#    '2. high': '225.6200',
#    '3. low': '216.2300',
#    '4. close': '222.1300',
#    '5. volume': '65299321'},
#   '2025-03-28': {'1. open': '221.6700',
#    '2. high': '223.8100',
#    '3. low': '217.6800',
#    '4. close': '217.9000',
#    '5. volume': '39818617'},
#   '2025-03-27': {'1. open': '221.3900',
#    '2. high': '224.9900',
#    '3. low': '220.5601',
#    '4. close': '223.8500',
#    '5. volume': '37094774'},
#   '2025-03-26': {'1. open': '223.5100',
#    '2. high': '225.0200',
#    '3. low': '220.4700',
#    '4. close': '221.5300',
#    '5. volume': '34532656'},
#   '2025-03-25': {'1. open': '220.7700',
#    '2. high': '224.1000',
#    '3. low': '220.0800',
#    '4. close': '223.7500',
#    '5. volume': '34493583'},
#   '2025-03-24': {'1. open': '221.0000',
#    '2. high': '221.4800',
#    '3. low': '218.5800',
#    '4. close': '220.7300',
#    '5. volume': '44299483'},
#   '2025-03-21': {'1. open': '211.5600',
#    '2. high': '218.8400',
#    '3. low': '211.2800',
#    '4. close': '218.2700',
#    '5. volume': '94127768'},
#   '2025-03-20': {'1. open': '213.9900',
#    '2. high': '217.4899',
#    '3. low': '212.2200',
#    '4. close': '214.1000',
#    '5. volume': '48862947'},
#   '2025-03-19': {'1. open': '214.2200',
#    '2. high': '218.7600',
#    '3. low': '213.7500',
#    '4. close': '215.2400',
#    '5. volume': '54385391'},
#   '2025-03-18': {'1. open': '214.1600',
#    '2. high': '215.1500',
#    '3. low': '211.4900',
#    '4. close': '212.6900',
#    '5. volume': '42432426'},
#   '2025-03-17': {'1. open': '213.3100',
#    '2. high': '215.2200',
#    '3. low': '209.9700',
#    '4. close': '214.0000',
#    '5. volume': '48073426'},
#   '2025-03-14': {'1. open': '211.2500',
#    '2. high': '213.9500',
#    '3. low': '209.5800',
#    '4. close': '213.4900',
#    '5. volume': '60107582'},
#   '2025-03-13': {'1. open': '215.9500',
#    '2. high': '216.8394',
#    '3. low': '208.4200',
#    '4. close': '209.6800',
#    '5. volume': '61368330'},
#   '2025-03-12': {'1. open': '220.1400',
#    '2. high': '221.7500',
#    '3. low': '214.9100',
#    '4. close': '216.9800',
#    '5. volume': '62547467'},
#   '2025-03-11': {'1. open': '223.8050',
#    '2. high': '225.8399',
#    '3. low': '217.4500',
#    '4. close': '220.8400',
#    '5. volume': '76137410'},
#   '2025-03-10': {'1. open': '235.5400',
#    '2. high': '236.1600',
#    '3. low': '224.2200',
#    '4. close': '227.4800',
#    '5. volume': '71451281'},
#   '2025-03-07': {'1. open': '235.1050',
#    '2. high': '241.3700',
#    '3. low': '234.7600',
#    '4. close': '239.0700',
#    '5. volume': '46273565'}}}
