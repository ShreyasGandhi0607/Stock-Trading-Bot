# %%
import setup
setup.init_django()

# %%
import helpers.clients as helper_clients

# %%
dataset_a = helper_clients.AlphaVantageAPIClient().get_stock_data()

# %%
dataset_p = helper_clients.PologyonAPIClient().get_stock_data()

# %%
dataset_a
# Out:
# [{'open_price': Decimal('212.5700'),
#   'close_price': Decimal('212.6000'),
#   'high_price': Decimal('212.6000'),
#   'low_price': Decimal('212.5000'),
#   'number_of_trades': None,
#   'volume': 9382,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 59, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.5499'),
#   'close_price': Decimal('212.5001'),
#   'high_price': Decimal('212.6500'),
#   'low_price': Decimal('212.5000'),
#   'number_of_trades': None,
#   'volume': 29541,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 58, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.5900'),
#   'close_price': Decimal('212.5100'),
#   'high_price': Decimal('212.6400'),
#   'low_price': Decimal('212.5000'),
#   'number_of_trades': None,
#   'volume': 7507,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 57, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.5000'),
#   'close_price': Decimal('212.5101'),
#   'high_price': Decimal('212.6000'),
#   'low_price': Decimal('212.5000'),
#   'number_of_trades': None,
#   'volume': 10226,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 56, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.5994'),
#   'close_price': Decimal('212.5000'),
#   'high_price': Decimal('212.6000'),
#   'low_price': Decimal('212.5000'),
#   'number_of_trades': None,
#   'volume': 8812,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 55, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.8800'),
#   'close_price': Decimal('212.5100'),
#   'high_price': Decimal('212.9200'),
#   'low_price': Decimal('212.5000'),
#   'number_of_trades': None,
#   'volume': 9503,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 54, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.6800'),
#   'close_price': Decimal('212.9200'),
#   'high_price': Decimal('212.9200'),
#   'low_price': Decimal('212.5250'),
#   'number_of_trades': None,
#   'volume': 17871,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 53, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.3600'),
#   'close_price': Decimal('212.7500'),
#   'high_price': Decimal('212.7800'),
#   'low_price': Decimal('212.3600'),
#   'number_of_trades': None,
#   'volume': 16038,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 52, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.1700'),
#   'close_price': Decimal('212.3700'),
#   'high_price': Decimal('212.3700'),
#   'low_price': Decimal('212.1400'),
#   'number_of_trades': None,
#   'volume': 9456,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 51, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.1200'),
#   'close_price': Decimal('212.2000'),
#   'high_price': Decimal('212.2000'),
#   'low_price': Decimal('212.1200'),
#   'number_of_trades': None,
#   'volume': 4609,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 50, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.1001'),
#   'close_price': Decimal('212.1500'),
#   'high_price': Decimal('212.1500'),
#   'low_price': Decimal('212.0500'),
#   'number_of_trades': None,
#   'volume': 7451,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 49, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.0000'),
#   'close_price': Decimal('212.1000'),
#   'high_price': Decimal('212.1400'),
#   'low_price': Decimal('212.0000'),
#   'number_of_trades': None,
#   'volume': 5186,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 48, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.0200'),
#   'close_price': Decimal('212.0800'),
#   'high_price': Decimal('212.2000'),
#   'low_price': Decimal('212.0000'),
#   'number_of_trades': None,
#   'volume': 6835,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 47, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.7800'),
#   'close_price': Decimal('212.0200'),
#   'high_price': Decimal('212.0200'),
#   'low_price': Decimal('211.7500'),
#   'number_of_trades': None,
#   'volume': 17295,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 46, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.8000'),
#   'close_price': Decimal('211.7900'),
#   'high_price': Decimal('211.8400'),
#   'low_price': Decimal('211.7500'),
#   'number_of_trades': None,
#   'volume': 13130,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 45, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.8000'),
#   'close_price': Decimal('211.8000'),
#   'high_price': Decimal('211.8200'),
#   'low_price': Decimal('211.7600'),
#   'number_of_trades': None,
#   'volume': 4304,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 44, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.5000'),
#   'close_price': Decimal('211.7999'),
#   'high_price': Decimal('211.8000'),
#   'low_price': Decimal('211.5000'),
#   'number_of_trades': None,
#   'volume': 8701,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 43, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.5000'),
#   'close_price': Decimal('211.5100'),
#   'high_price': Decimal('211.5100'),
#   'low_price': Decimal('211.4105'),
#   'number_of_trades': None,
#   'volume': 10244,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 42, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.5000'),
#   'close_price': Decimal('211.6345'),
#   'high_price': Decimal('211.6400'),
#   'low_price': Decimal('211.4000'),
#   'number_of_trades': None,
#   'volume': 6756,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 41, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.4000'),
#   'close_price': Decimal('211.4001'),
#   'high_price': Decimal('211.5000'),
#   'low_price': Decimal('211.4000'),
#   'number_of_trades': None,
#   'volume': 5619,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 40, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.4000'),
#   'close_price': Decimal('211.4000'),
#   'high_price': Decimal('211.5100'),
#   'low_price': Decimal('211.4000'),
#   'number_of_trades': None,
#   'volume': 10134,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 39, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.4500'),
#   'close_price': Decimal('211.4000'),
#   'high_price': Decimal('211.5000'),
#   'low_price': Decimal('211.4000'),
#   'number_of_trades': None,
#   'volume': 4128,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 38, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.4800'),
#   'close_price': Decimal('211.5000'),
#   'high_price': Decimal('211.5000'),
#   'low_price': Decimal('211.4000'),
#   'number_of_trades': None,
#   'volume': 18607,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 37, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.4500'),
#   'close_price': Decimal('211.4800'),
#   'high_price': Decimal('211.4800'),
#   'low_price': Decimal('211.4001'),
#   'number_of_trades': None,
#   'volume': 5767,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 36, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.5000'),
#   'close_price': Decimal('211.4500'),
#   'high_price': Decimal('211.5000'),
#   'low_price': Decimal('211.4000'),
#   'number_of_trades': None,
#   'volume': 7621,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 35, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.3300'),
#   'close_price': Decimal('211.4000'),
#   'high_price': Decimal('211.5500'),
#   'low_price': Decimal('211.2600'),
#   'number_of_trades': None,
#   'volume': 10269,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 34, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.2300'),
#   'close_price': Decimal('211.3000'),
#   'high_price': Decimal('211.3000'),
#   'low_price': Decimal('211.2000'),
#   'number_of_trades': None,
#   'volume': 7019,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 33, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.1900'),
#   'close_price': Decimal('211.2391'),
#   'high_price': Decimal('211.3000'),
#   'low_price': Decimal('211.1800'),
#   'number_of_trades': None,
#   'volume': 5745,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 32, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.1900'),
#   'close_price': Decimal('211.1900'),
#   'high_price': Decimal('211.3000'),
#   'low_price': Decimal('211.1200'),
#   'number_of_trades': None,
#   'volume': 5639,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 31, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.0200'),
#   'close_price': Decimal('211.1800'),
#   'high_price': Decimal('211.2000'),
#   'low_price': Decimal('211.0200'),
#   'number_of_trades': None,
#   'volume': 6408,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 30, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.2200'),
#   'close_price': Decimal('211.0500'),
#   'high_price': Decimal('211.2500'),
#   'low_price': Decimal('211.0100'),
#   'number_of_trades': None,
#   'volume': 12421,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 29, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.4499'),
#   'close_price': Decimal('211.2500'),
#   'high_price': Decimal('211.4499'),
#   'low_price': Decimal('211.2000'),
#   'number_of_trades': None,
#   'volume': 12696,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 28, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.6000'),
#   'close_price': Decimal('211.4000'),
#   'high_price': Decimal('211.6000'),
#   'low_price': Decimal('211.4000'),
#   'number_of_trades': None,
#   'volume': 7768,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 27, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.7210'),
#   'close_price': Decimal('211.5999'),
#   'high_price': Decimal('211.7400'),
#   'low_price': Decimal('211.5900'),
#   'number_of_trades': None,
#   'volume': 9593,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 26, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.7600'),
#   'close_price': Decimal('211.7300'),
#   'high_price': Decimal('211.7700'),
#   'low_price': Decimal('211.7200'),
#   'number_of_trades': None,
#   'volume': 2566,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 25, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.7800'),
#   'close_price': Decimal('211.7600'),
#   'high_price': Decimal('211.8200'),
#   'low_price': Decimal('211.7500'),
#   'number_of_trades': None,
#   'volume': 2341,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 24, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.8900'),
#   'close_price': Decimal('211.7026'),
#   'high_price': Decimal('211.8900'),
#   'low_price': Decimal('211.7000'),
#   'number_of_trades': None,
#   'volume': 7034,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 23, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.9000'),
#   'close_price': Decimal('211.8200'),
#   'high_price': Decimal('211.9900'),
#   'low_price': Decimal('211.8000'),
#   'number_of_trades': None,
#   'volume': 4332,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 22, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.9600'),
#   'close_price': Decimal('211.9000'),
#   'high_price': Decimal('212.0500'),
#   'low_price': Decimal('211.8000'),
#   'number_of_trades': None,
#   'volume': 11199,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 21, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.0100'),
#   'close_price': Decimal('212.0500'),
#   'high_price': Decimal('212.1100'),
#   'low_price': Decimal('211.9201'),
#   'number_of_trades': None,
#   'volume': 3260,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 20, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.0900'),
#   'close_price': Decimal('211.9900'),
#   'high_price': Decimal('212.1000'),
#   'low_price': Decimal('211.9000'),
#   'number_of_trades': None,
#   'volume': 1930,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 19, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.0001'),
#   'close_price': Decimal('212.0900'),
#   'high_price': Decimal('212.0900'),
#   'low_price': Decimal('211.9000'),
#   'number_of_trades': None,
#   'volume': 4990,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 18, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.0300'),
#   'close_price': Decimal('212.0000'),
#   'high_price': Decimal('212.0500'),
#   'low_price': Decimal('212.0000'),
#   'number_of_trades': None,
#   'volume': 5594,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 17, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.1000'),
#   'close_price': Decimal('212.0100'),
#   'high_price': Decimal('212.1100'),
#   'low_price': Decimal('212.0100'),
#   'number_of_trades': None,
#   'volume': 2285,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 16, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.1700'),
#   'close_price': Decimal('212.1000'),
#   'high_price': Decimal('212.1800'),
#   'low_price': Decimal('212.1000'),
#   'number_of_trades': None,
#   'volume': 1929,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 15, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.1994'),
#   'close_price': Decimal('212.1700'),
#   'high_price': Decimal('212.2000'),
#   'low_price': Decimal('212.1500'),
#   'number_of_trades': None,
#   'volume': 1295,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 14, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.2200'),
#   'close_price': Decimal('212.1600'),
#   'high_price': Decimal('212.2500'),
#   'low_price': Decimal('212.1500'),
#   'number_of_trades': None,
#   'volume': 3468,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 13, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.1600'),
#   'close_price': Decimal('212.2200'),
#   'high_price': Decimal('212.2500'),
#   'low_price': Decimal('212.1200'),
#   'number_of_trades': None,
#   'volume': 4274,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 12, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.0200'),
#   'close_price': Decimal('212.1316'),
#   'high_price': Decimal('212.1316'),
#   'low_price': Decimal('212.0100'),
#   'number_of_trades': None,
#   'volume': 4978,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 11, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.0000'),
#   'close_price': Decimal('212.0500'),
#   'high_price': Decimal('212.0600'),
#   'low_price': Decimal('212.0000'),
#   'number_of_trades': None,
#   'volume': 2030,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 10, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.0900'),
#   'close_price': Decimal('212.0000'),
#   'high_price': Decimal('212.1500'),
#   'low_price': Decimal('212.0000'),
#   'number_of_trades': None,
#   'volume': 3475,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 9, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.1010'),
#   'close_price': Decimal('212.0900'),
#   'high_price': Decimal('212.1900'),
#   'low_price': Decimal('212.0270'),
#   'number_of_trades': None,
#   'volume': 4842,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 8, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.2000'),
#   'close_price': Decimal('212.1001'),
#   'high_price': Decimal('212.2000'),
#   'low_price': Decimal('212.1000'),
#   'number_of_trades': None,
#   'volume': 6432,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 7, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.1500'),
#   'close_price': Decimal('212.1500'),
#   'high_price': Decimal('212.2100'),
#   'low_price': Decimal('212.0068'),
#   'number_of_trades': None,
#   'volume': 21583,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 6, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.9900'),
#   'close_price': Decimal('212.0000'),
#   'high_price': Decimal('212.1500'),
#   'low_price': Decimal('211.9600'),
#   'number_of_trades': None,
#   'volume': 6258,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 5, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.9800'),
#   'close_price': Decimal('211.9900'),
#   'high_price': Decimal('212.0700'),
#   'low_price': Decimal('211.9600'),
#   'number_of_trades': None,
#   'volume': 7035,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 4, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.9200'),
#   'close_price': Decimal('211.9700'),
#   'high_price': Decimal('211.9900'),
#   'low_price': Decimal('211.9200'),
#   'number_of_trades': None,
#   'volume': 3842,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 3, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.9800'),
#   'close_price': Decimal('211.9740'),
#   'high_price': Decimal('211.9900'),
#   'low_price': Decimal('211.9200'),
#   'number_of_trades': None,
#   'volume': 3563,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 2, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.0000'),
#   'close_price': Decimal('211.9200'),
#   'high_price': Decimal('212.0700'),
#   'low_price': Decimal('211.9200'),
#   'number_of_trades': None,
#   'volume': 4252,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 1, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.3000'),
#   'close_price': Decimal('212.0000'),
#   'high_price': Decimal('212.3000'),
#   'low_price': Decimal('212.0000'),
#   'number_of_trades': None,
#   'volume': 12744,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 23, 0, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.2900'),
#   'close_price': Decimal('212.2500'),
#   'high_price': Decimal('212.5000'),
#   'low_price': Decimal('212.0800'),
#   'number_of_trades': None,
#   'volume': 7467,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 59, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.9500'),
#   'close_price': Decimal('212.2000'),
#   'high_price': Decimal('212.2900'),
#   'low_price': Decimal('211.9200'),
#   'number_of_trades': None,
#   'volume': 10017,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 58, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.9200'),
#   'close_price': Decimal('211.9500'),
#   'high_price': Decimal('212.0000'),
#   'low_price': Decimal('211.9000'),
#   'number_of_trades': None,
#   'volume': 3015,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 57, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.0000'),
#   'close_price': Decimal('211.9400'),
#   'high_price': Decimal('212.0000'),
#   'low_price': Decimal('211.9000'),
#   'number_of_trades': None,
#   'volume': 7443,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 56, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.0560'),
#   'close_price': Decimal('211.9500'),
#   'high_price': Decimal('212.0600'),
#   'low_price': Decimal('211.9400'),
#   'number_of_trades': None,
#   'volume': 9461,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 55, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.9200'),
#   'close_price': Decimal('212.0200'),
#   'high_price': Decimal('212.0600'),
#   'low_price': Decimal('211.8600'),
#   'number_of_trades': None,
#   'volume': 9384,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 54, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.8000'),
#   'close_price': Decimal('211.9200'),
#   'high_price': Decimal('211.9999'),
#   'low_price': Decimal('211.7100'),
#   'number_of_trades': None,
#   'volume': 10978,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 53, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.8000'),
#   'close_price': Decimal('211.8000'),
#   'high_price': Decimal('211.9000'),
#   'low_price': Decimal('211.7000'),
#   'number_of_trades': None,
#   'volume': 7401,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 52, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.8200'),
#   'close_price': Decimal('211.8000'),
#   'high_price': Decimal('211.9800'),
#   'low_price': Decimal('211.6001'),
#   'number_of_trades': None,
#   'volume': 9673,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 51, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.8400'),
#   'close_price': Decimal('211.9785'),
#   'high_price': Decimal('212.0000'),
#   'low_price': Decimal('211.8200'),
#   'number_of_trades': None,
#   'volume': 3091,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 50, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.9000'),
#   'close_price': Decimal('211.8200'),
#   'high_price': Decimal('211.9500'),
#   'low_price': Decimal('211.8200'),
#   'number_of_trades': None,
#   'volume': 5253,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 49, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.8300'),
#   'close_price': Decimal('211.8700'),
#   'high_price': Decimal('211.9500'),
#   'low_price': Decimal('211.8200'),
#   'number_of_trades': None,
#   'volume': 6513,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 48, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.1505'),
#   'close_price': Decimal('211.9000'),
#   'high_price': Decimal('212.2000'),
#   'low_price': Decimal('211.9000'),
#   'number_of_trades': None,
#   'volume': 15457,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 47, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.3000'),
#   'close_price': Decimal('212.2000'),
#   'high_price': Decimal('212.3300'),
#   'low_price': Decimal('212.1511'),
#   'number_of_trades': None,
#   'volume': 4752,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 46, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.3000'),
#   'close_price': Decimal('212.2900'),
#   'high_price': Decimal('212.4000'),
#   'low_price': Decimal('212.1500'),
#   'number_of_trades': None,
#   'volume': 9504,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 45, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.3000'),
#   'close_price': Decimal('212.3097'),
#   'high_price': Decimal('212.3100'),
#   'low_price': Decimal('212.1000'),
#   'number_of_trades': None,
#   'volume': 5098,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 44, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.3100'),
#   'close_price': Decimal('212.2500'),
#   'high_price': Decimal('212.5000'),
#   'low_price': Decimal('212.0715'),
#   'number_of_trades': None,
#   'volume': 7371,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 43, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.9100'),
#   'close_price': Decimal('212.2515'),
#   'high_price': Decimal('212.3000'),
#   'low_price': Decimal('211.8300'),
#   'number_of_trades': None,
#   'volume': 16414,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 42, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.7000'),
#   'close_price': Decimal('211.8400'),
#   'high_price': Decimal('211.9400'),
#   'low_price': Decimal('211.7000'),
#   'number_of_trades': None,
#   'volume': 8923,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 41, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.7000'),
#   'close_price': Decimal('211.7001'),
#   'high_price': Decimal('212.0000'),
#   'low_price': Decimal('211.5500'),
#   'number_of_trades': None,
#   'volume': 15322,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 40, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.7999'),
#   'close_price': Decimal('211.7498'),
#   'high_price': Decimal('211.8000'),
#   'low_price': Decimal('211.6400'),
#   'number_of_trades': None,
#   'volume': 7728,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 39, tzinfo=<UTC>)},
#  {'open_price': Decimal('211.8000'),
#   'close_price': Decimal('211.8000'),
#   'high_price': Decimal('211.9900'),
#   'low_price': Decimal('211.7200'),
#   'number_of_trades': None,
#   'volume': 15236,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 38, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.3000'),
#   'close_price': Decimal('211.8400'),
#   'high_price': Decimal('212.5000'),
#   'low_price': Decimal('211.7900'),
#   'number_of_trades': None,
#   'volume': 21391,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 37, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.6700'),
#   'close_price': Decimal('212.1500'),
#   'high_price': Decimal('212.7500'),
#   'low_price': Decimal('212.1500'),
#   'number_of_trades': None,
#   'volume': 12216,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 36, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.8700'),
#   'close_price': Decimal('212.7000'),
#   'high_price': Decimal('212.8999'),
#   'low_price': Decimal('212.7000'),
#   'number_of_trades': None,
#   'volume': 13889,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 35, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.9500'),
#   'close_price': Decimal('212.8992'),
#   'high_price': Decimal('212.9800'),
#   'low_price': Decimal('212.8992'),
#   'number_of_trades': None,
#   'volume': 9698,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 34, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.9600'),
#   'close_price': Decimal('212.9700'),
#   'high_price': Decimal('212.9900'),
#   'low_price': Decimal('212.9100'),
#   'number_of_trades': None,
#   'volume': 3073,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 33, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.9400'),
#   'close_price': Decimal('212.9600'),
#   'high_price': Decimal('212.9900'),
#   'low_price': Decimal('212.9000'),
#   'number_of_trades': None,
#   'volume': 4881,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 32, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.9800'),
#   'close_price': Decimal('212.9687'),
#   'high_price': Decimal('212.9900'),
#   'low_price': Decimal('212.9000'),
#   'number_of_trades': None,
#   'volume': 14035,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 31, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.8300'),
#   'close_price': Decimal('212.9000'),
#   'high_price': Decimal('212.9800'),
#   'low_price': Decimal('212.8000'),
#   'number_of_trades': None,
#   'volume': 3256,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 30, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.8100'),
#   'close_price': Decimal('212.8000'),
#   'high_price': Decimal('212.8600'),
#   'low_price': Decimal('212.8000'),
#   'number_of_trades': None,
#   'volume': 9622,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 29, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.7800'),
#   'close_price': Decimal('212.8100'),
#   'high_price': Decimal('212.9000'),
#   'low_price': Decimal('212.7700'),
#   'number_of_trades': None,
#   'volume': 8975,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 28, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.7601'),
#   'close_price': Decimal('212.7704'),
#   'high_price': Decimal('212.8967'),
#   'low_price': Decimal('212.7600'),
#   'number_of_trades': None,
#   'volume': 5408,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 27, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.8800'),
#   'close_price': Decimal('212.7700'),
#   'high_price': Decimal('212.9000'),
#   'low_price': Decimal('212.7400'),
#   'number_of_trades': None,
#   'volume': 9947,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 26, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.8900'),
#   'close_price': Decimal('212.9000'),
#   'high_price': Decimal('212.9899'),
#   'low_price': Decimal('212.7500'),
#   'number_of_trades': None,
#   'volume': 17775,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 25, tzinfo=<UTC>)},
#  {'open_price': Decimal('212.6300'),
#   'close_price': Decimal('212.9000'),
#   'high_price': Decimal('212.9900'),
#   'low_price': Decimal('207.5700'),
#   'number_of_trades': None,
#   'volume': 59490,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 24, tzinfo=<UTC>)},
#  {'open_price': Decimal('213.0000'),
#   'close_price': Decimal('212.8299'),
#   'high_price': Decimal('213.0772'),
#   'low_price': Decimal('212.6300'),
#   'number_of_trades': None,
#   'volume': 19332,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 23, tzinfo=<UTC>)},
#  {'open_price': Decimal('213.0999'),
#   'close_price': Decimal('213.0611'),
#   'high_price': Decimal('213.1240'),
#   'low_price': Decimal('213.0300'),
#   'number_of_trades': None,
#   'volume': 7096,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 22, tzinfo=<UTC>)},
#  {'open_price': Decimal('213.0600'),
#   'close_price': Decimal('213.0600'),
#   'high_price': Decimal('213.1000'),
#   'low_price': Decimal('213.0000'),
#   'number_of_trades': None,
#   'volume': 5596,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 21, tzinfo=<UTC>)},
#  {'open_price': Decimal('213.0500'),
#   'close_price': Decimal('213.1800'),
#   'high_price': Decimal('213.1800'),
#   'low_price': Decimal('213.0500'),
#   'number_of_trades': None,
#   'volume': 7913,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2025, 7, 31, 22, 20, tzinfo=<UTC>)}]

# %%
dataset_p
# Out:
# [{'open_price': 214.7,
#   'close_price': 213.88,
#   'high_price': 215.24,
#   'low_price': 213.4,
#   'number_of_trades': 409972,
#   'volume': 40268781.0,
#   'volume_weighted_average': 214.1284,
#   'time': datetime.datetime(2025, 7, 25, 4, 0, tzinfo=<UTC>)},
#  {'open_price': 214.03,
#   'close_price': 214.05,
#   'high_price': 214.845,
#   'low_price': 213.06,
#   'number_of_trades': 425354,
#   'volume': 37858017.0,
#   'volume_weighted_average': 214.04,
#   'time': datetime.datetime(2025, 7, 28, 4, 0, tzinfo=<UTC>)},
#  {'open_price': 214.175,
#   'close_price': 211.27,
#   'high_price': 214.81,
#   'low_price': 210.82,
#   'number_of_trades': 537963,
#   'volume': 51411723.0,
#   'volume_weighted_average': 212.1244,
#   'time': datetime.datetime(2025, 7, 29, 4, 0, tzinfo=<UTC>)},
#  {'open_price': 211.895,
#   'close_price': 209.05,
#   'high_price': 212.39,
#   'low_price': 207.72,
#   'number_of_trades': 542351,
#   'volume': 45512514.0,
#   'volume_weighted_average': 209.5067,
#   'time': datetime.datetime(2025, 7, 30, 4, 0, tzinfo=<UTC>)}]
